# %% [markdown]
# <a href="https://colab.research.google.com/github/santanu-dey/aws/blob/master/Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Data

# %%
import pandas as pd

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
val_housing_win_df = pd.read_csv("https://raw.githubusercontent.com/noahgift/socialpowernba/master/data/nba_2017_att_val_elo_win_housing.csv")

# %%
val_housing_win_df.head()
# Out:
#                TEAM  GMS  PCT_ATTENDANCE  WINNING_SEASON  \
# 0     Chicago Bulls   41             104               1
# 1  Dallas Mavericks   41             103               0
# 2  Sacramento Kings   41             101               0
# 3        Miami Heat   41             100               1
# 4   Toronto Raptors   41             100               1
#
#    TOTAL_ATTENDANCE_MILLIONS  VALUE_MILLIONS   ELO  CONF       COUNTY  \
# 0                      0.889            2500  1519  East         Cook
# 1                      0.811            1450  1420  West       Dallas
# 2                      0.722            1075  1393  West   Sacremento
# 3                      0.805            1350  1569  East   Miami-Dade
# 4                      0.813            1125  1600  East  York-County
#
#    MEDIAN_HOME_PRICE_COUNTY_MILLIONS  COUNTY_POPULATION_MILLIONS
# 0                         269900.000                       5.200
# 1                         314990.000                       2.570
# 2                         343950.000                       1.510
# 3                         389000.000                       2.710
# 4                         390000.000                       1.100

# %%
numerical_housing_df = val_housing_win_df[["TOTAL_ATTENDANCE_MILLIONS", "ELO", "VALUE_MILLIONS", "MEDIAN_HOME_PRICE_COUNTY_MILLIONS"]].copy()

# %% [markdown]
# Now we select the numerical fields in a new dataframe using copy.
# Interesting thing is that the float number formatting option is still working in the copied dataframe.

# %%
numerical_housing_df.head()
# Out:
#    TOTAL_ATTENDANCE_MILLIONS   ELO  VALUE_MILLIONS  \
# 0                      0.889  1519            2500
# 1                      0.811  1420            1450
# 2                      0.722  1393            1075
# 3                      0.805  1569            1350
# 4                      0.813  1600            1125
#
#    MEDIAN_HOME_PRICE_COUNTY_MILLIONS
# 0                         269900.000
# 1                         314990.000
# 2                         343950.000
# 3                         389000.000
# 4                         390000.000

# %% [markdown]
# # Format Numerical Fields for ML Function

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
print(scaler.fit(numerical_housing_df))
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
print(scaler.transform(numerical_housing_df))
# Out:
# [[1.         0.41898148 0.68627451 0.08776879]
#  [0.72637903 0.18981481 0.2745098  0.11603661]
#  [0.41067502 0.12731481 0.12745098 0.13419221]
#  [0.70531986 0.53472222 0.23529412 0.16243496]
#  [0.73232332 0.60648148 0.14705882 0.16306188]
#  [0.62487072 0.68981481 0.49019608 0.31038806]
#  [0.83819102 0.47916667 0.17647059 0.00476459]
#  [0.6983872  1.         0.7254902  0.39188139]
#  [0.49678606 0.47453704 0.10784314 0.04993825]
#  [0.72417286 0.08333333 1.         1.        ]
#  [0.54749962 0.57638889 0.56862745 0.23139615]
#  [0.60477873 0.06712963 0.88235294 0.31038806]
#  [0.65812204 0.52083333 0.11764706 0.184816  ]
#  [0.52863955 0.74768519 0.16666667 0.08156228]
#  [0.70957335 0.64583333 0.0627451  0.13983449]
#  [0.43166712 0.03240741 0.06666667 0.10657639]
#  [0.20301662 0.33333333 0.         0.10350448]
#  [0.31881029 0.61111111 0.35294118 0.09062441]
#  [0.36376665 0.00462963 0.1372549  0.10350448]
#  [0.27883458 0.43518519 0.05098039 0.00946649]
#  [0.25319364 0.33333333 0.01568627 0.01573569]
#  [0.3708405  0.28935185 0.01176471 0.10977023]
#  [0.37053693 0.         0.01960784 0.03140869]
#  [0.17197852 0.32638889 0.05294118 0.14738888]
#  [0.09538753 0.0787037  0.41176471 0.40756065]
#  [0.15307963 0.37962963 0.01372549 0.        ]
#  [0.32306025 0.57638889 0.09803922 0.27336844]
#  [0.         0.49537037 0.05490196 0.21885775]
#  [0.00571132 0.28935185 0.00784314 0.12758322]
#  [0.17492596 0.23842593 0.05882353 0.10663281]]

# %% [markdown]
# # Cluster the data using Scikit learn

# %%
from sklearn.cluster import KMeans
k_means = KMeans(n_clusters=5)
kmeans = k_means.fit(scaler.transform(numerical_housing_df))
val_housing_win_df['cluster'] = kmeans.labels_
val_housing_win_df.head(50)
# Out:
#                       TEAM  GMS  PCT_ATTENDANCE  WINNING_SEASON  \
# 0            Chicago Bulls   41             104               1
# 1         Dallas Mavericks   41             103               0
# 2         Sacramento Kings   41             101               0
# 3               Miami Heat   41             100               1
# 4          Toronto Raptors   41             100               1
# 5     Los Angeles Clippers   41             100               1
# 6      Cleveland Cavaliers   41             100               1
# 7    Golden State Warriors   41             100               1
# 8    Oklahoma City Thunder   41             100               1
# 9          New York Knicks   41             100               0
# 10          Boston Celtics   41             100               1
# 11      Los Angeles Lakers   41              99               0
# 12  Portland Trail Blazers   41              99               1
# 13       San Antonio Spurs   41              99               1
# 14               Utah Jazz   41              99               1
# 15           Orlando Magic   41              94               0
# 16    New Orleans Pelicans   41              94               0
# 17         Houston Rockets   41              94               1
# 18            Phoenix Suns   41              94               0
# 19          Indiana Pacers   41              92               1
# 20       Memphis Grizzlies   41              91               1
# 21       Charlotte Hornets   41              91               0
# 22      Philadelphia 76ers   41              85               0
# 23           Atlanta Hawks   41              85               1
# 24           Brooklyn Nets   41              85               0
# 25         Milwaukee Bucks   41              85               1
# 26      Washington Wizards   41              84               1
# 27          Denver Nuggets   41              77               0
# 28  Minnesota Timberwolves   41              77               0
# 29         Detroit Pistons   41              72               0
#
#     TOTAL_ATTENDANCE_MILLIONS  VALUE_MILLIONS   ELO  CONF  \
# 0                       0.889            2500  1519  East
# 1                       0.811            1450  1420  West
# 2                       0.722            1075  1393  West
# 3                       0.805            1350  1569  East
# 4                       0.813            1125  1600  East
# 5                       0.783            2000  1636  West
# 6                       0.843            1200  1545  East
# 7                       0.803            2600  1770  West
# 8                       0.746            1025  1543  West
# 9                       0.811            3300  1374  East
# 10                      0.761            2200  1587  East
# 11                      0.777            3000  1367  West
# 12                      0.792            1050  1563  West
# 13                      0.755            1175  1661  West
# 14                      0.807             910  1617  West
# 15                      0.728             920  1352  East
# 16                      0.663             750  1482  West
# 17                      0.696            1650  1602  West
# 18                      0.709            1100  1340  West
# 19                      0.685             880  1526  East
# 20                      0.677             790  1482  West
# 21                      0.711             780  1463  East
# 22                      0.711             800  1338  East
# 23                      0.654             885  1479  East
# 24                      0.633            1800  1372  East
# 25                      0.649             785  1502  East
# 26                      0.697            1000  1587  East
# 27                      0.606             890  1552  West
# 28                      0.607             770  1463  West
# 29                      0.655             900  1441  East
#
#                   COUNTY  MEDIAN_HOME_PRICE_COUNTY_MILLIONS  \
# 0                   Cook                         269900.000
# 1                 Dallas                         314990.000
# 2             Sacremento                         343950.000
# 3             Miami-Dade                         389000.000
# 4            York-County                         390000.000
# 5            Los Angeles                         625000.000
# 6               Cuyahoga                         137500.000
# 7                Alameda                         754990.000
# 8               Oklahoma                         209556.500
# 9               New York                        1725000.000
# 10               Suffolk                         499000.000
# 11           Los Angeles                         625000.000
# 12             Multnomah                         424700.000
# 13                 Bexar                         260000.000
# 14             Salt Lake                         352950.000
# 15                Orange                         299900.000
# 16               Orleans                         295000.000
# 17                Harris                         274455.000
# 18              Maricopa                         295000.000
# 19                Marion                         145000.000
# 20                Shelby                         155000.000
# 21           Mecklenburg                         304994.500
# 22          Philadelphia                         180000.000
# 23                Fulton                         365000.000
# 24                 Kings                         780000.000
# 25             Milwaukee                         129900.000
# 26  District of Columbia                         565950.000
# 27                Denver                         479000.000
# 28              Hennepin                         333408.000
# 29               Oakland                         299990.000
#
#     COUNTY_POPULATION_MILLIONS  cluster
# 0                        5.200        1
# 1                        2.570        3
# 2                        1.510        0
# 3                        2.710        3
# 4                        1.100        3
# 5                       10.100        1
# 6                        1.260        3
# 7                        1.500        1
# 8                        0.780        3
# 9                        1.640        4
# 10                       1.500        1
# 11                      10.100        1
# 12                       0.790        3
# 13                       1.890        3
# 14                       1.100        3
# 15                       1.290        0
# 16                       0.390        2
# 17                       4.580        2
# 18                       4.200        0
# 19                       0.900        2
# 20                       0.940        2
# 21                       1.030        2
# 22                       1.570        0
# 23                       1.010        2
# 24                       2.640        0
# 25                       0.960        2
# 26                       0.680        2
# 27                       0.680        2
# 28                       1.220        2
# 29                       1.240        2

# %% [markdown]
# # Now Plot the data in a Graph
